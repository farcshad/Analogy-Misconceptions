# %%
from dotenv import load_dotenv
import os

load_dotenv()  # looks for .env in the current directory
# Out:
# True

# %%
api_key = os.getenv("API_KEY")

# %%
import model_loader

# %%
model = model_loader.load_model_avalai("gemini-2.5-flash-lite-preview-09-2025")

# %%
model.invoke([{'role': 'user', 'content': "Hello, world!"}])
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 5, 'total_tokens': 14, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': None, 'text_tokens': 5, 'image_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gemini-2.5-flash-lite-preview-09-2025', 'system_fingerprint': None, 'id': 'k6oxaYX0DLjnxN8PgcD2mQE', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ad2f7c4f-9c62-48c2-87dd-2639c6c767ad-0', usage_metadata={'input_tokens': 5, 'output_tokens': 9, 'total_tokens': 14, 'input_token_details': {}, 'output_token_details': {}})
